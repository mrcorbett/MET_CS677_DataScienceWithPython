# %% [markdown]
# ### Seaborn - Visualizing Data Distributions

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="ticks")

# %% [markdown]
# #### Univariate Distributions
#  - distplot() - draw a histogram and file a KDE (kernel density estimate)

# %%
np.random.seed(123)
x = np.random.normal(size=500)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
sns.distplot(x, bins=20, kde=False, rug=True);

# %%
sns.distplot(x, bins=20, hist=False, rug=True);

# %%
# kdeplot provides more options

sns.kdeplot(x, shade=True);

# %%
sns.kdeplot(x, shade=True)
sns.rugplot(x);

# %% [markdown]
# ### Bivariate distributions
#  - jointplot()

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x="total_bill", y="tip", data=tips);

# %%
# For large datasets, hexbin plot shows counts of observations

sns.jointplot(x="total_bill", y="tip", 
              kind="hex", data=tips);

# %%
# Use kde to show contour plot

sns.jointplot(x="total_bill", y="tip", 
              kind="kde", data=tips);

# %% [markdown]
# ### Pairwise relationships

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris);

# %% [markdown]
# ### JointGrid

# %%
# Grid for drawing a bivariate plot with marginal univariate plots.
# Set up the grid of subplots.
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

# %%
# regplot:  Plot data and a linear regression model fit.
# distplot:  Flexibly plot a univariate distribution of observations.

g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot_joint(plt.scatter)
g.plot_marginals(sns.distplot, kde=False);

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)

g = g.plot_joint(plt.scatter, color="m", edgecolor="yellow")

g.ax_marg_x.hist(tips["total_bill"], color="blue", alpha=.2,
                      bins=np.arange(0, 60, 5))

g.ax_marg_y.hist(tips["tip"], color="red", alpha=.2,
                      orientation="horizontal",
                      bins=np.arange(0, 12, 1));
